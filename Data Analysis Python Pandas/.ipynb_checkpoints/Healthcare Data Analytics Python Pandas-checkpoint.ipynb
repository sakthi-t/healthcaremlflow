# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import chi2_contingency

# %%
import os
from google.cloud import bigquery
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = 'biquerykey.json'
client = bigquery.Client()

# %%
sql_query = """
SELECT * FROM `bigqueryimdb.healthcare.dim_patients` WHERE patient_id = 1000

"""

# %%
query_job = client.query(sql_query)

# %%
query_job
# Out:
# QueryJob<project=bigqueryimdb, location=US, id=44339682-aeea-4abc-90d3-18809f509a41>

# %%
for row in query_job.result():
    print(row)
# Out:
# Row((1000, datetime.date(1957, 7, 2), 254734595276, 912998937864, 'achang@example.org', 'Eswar', 'Rajendran', 'Mr. Eswar Rajendran', 'Male', 165, 94, 34.5, 'Alwarpet', 13.033, 80.251), {'patient_id': 0, 'date_of_birth': 1, 'aadhar_number': 2, 'mobile_number': 3, 'email': 4, 'first_name': 5, 'last_name': 6, 'full_name': 7, 'gender': 8, 'height': 9, 'weight': 10, 'bmi': 11, 'area': 12, 'latitude': 13, 'longitude': 14})

# %%
dim_patients_table = """SELECT * FROM `bigqueryimdb.healthcare.dim_patients`;"""

# %%
fact_visits_table = """SELECT * FROM `bigqueryimdb.healthcare.fact_visits`;"""

# %%
df_patients = client.query(dim_patients_table).to_dataframe()

# %%
df_visits = client.query(fact_visits_table).to_dataframe() # reading the patients visits fact table

# %%
df_patients.head()
# Out:
#    patient_id date_of_birth  aadhar_number  mobile_number  \
# 0        1053    1973-04-24   317320301691   917108801293
# 1        1111    1990-06-25   228343284543   914826294247
# 2        1128    1949-01-06   819907684377   915974958012
# 3        1132    1960-01-13   612453976088   918818220132
# 4        1212    1967-04-17   384827959428   915647948599
#
#                           email    first_name   last_name  \
# 0             frose@example.net       Pandian    Govindan
# 1  danielleanderson@example.com  Chandrasekar  Bhagavathi
# 2        jerryfrank@example.net        Naveen    Rathinam
# 3         moodyryan@example.com        Harish     Senthil
# 4        scottjones@example.com  Chandrasekar  Palanisamy
#
#                      full_name gender  height  weight   bmi       area  \
# 0         Mr. Pandian Govindan   Male     169      57  20.0  Mandaveli
# 1  Mr. Chandrasekar Bhagavathi   Male     157      65  26.4  Mandaveli
# 2          Mr. Naveen Rathinam   Male     151      57  25.0  Mandaveli
# 3           Mr. Harish Senthil   Male     169      96  33.6  Mandaveli
# 4  Mr. Chandrasekar Palanisamy   Male     155      75  31.2  Mandaveli
#
#    latitude  longitude
# 0    13.029     80.259
# 1    13.029     80.259
# 2    13.029     80.259
# 3    13.029     80.259
# 4    13.029     80.259

# %%
df_visits.head()
# Out:
#    patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 0        1967   2024-03-13     85    5.0                 96
# 1        2172   2023-11-16    114    5.0                108
# 2        2239   2023-11-12     61    5.0                134
# 3        2749   2023-04-29     94    5.0                102
# 4        3635   2023-08-07     83    5.0                 90
#
#    diastolic_pressure
# 0                  80
# 1                  80
# 2                  80
# 3                  80
# 4                  80

# %%
df_patients.columns
# Out:
# Index(['patient_id', 'date_of_birth', 'aadhar_number', 'mobile_number',
#        'email', 'first_name', 'last_name', 'full_name', 'gender', 'height',
#        'weight', 'bmi', 'area', 'latitude', 'longitude'],
#       dtype='object')

# %%
df_visits.columns
# Out:
# Index(['patient_id', 'visited_date', 'sugar', 'hba1c', 'systolic_pressure',
#        'diastolic_pressure'],
#       dtype='object')

# %% [markdown]
# ## Data Definition
#
# ### df_patients contains the following columns
#     - patinet_id - patients id
#     - date_of_birth - Date of birth of patients
#     - aadhar_number - Aadhar number of patients
#     - mobile_number - Mobile number of patients
#     - email - Email of patients
#     - first_name - first name of patients
#     - full_name - full name of patients
#     - gender - Gender of patients
#     - height - height of patients
#     - weight - weight of patients
#     - area - The area in Chennai where the patient lives
#     - latitude - latitude of the patient's area
#     - longitude - longitude of the patients' area
#
# ### df_visits contains the following columns
#     - patient_id - patients id
#     - visited_date - Date the patient visited the patients
#     - sugar - Sugar level of the patient
#     - hba1c - HBA1C level of the patient
#     - systolic_pressure - Systolic blood pressure level of the patients
#     - diastolic_pressure - Diastolic pressure level of the patients

# %% [markdown]
# ## Find the mean sugar, HBA1C, blood pressure of the patients

# %%
# mean sugar of patients
df_visits['sugar'].mean()
# Out:
# 309.1905066439281

# %%
# mean HBA1C of patients
df_visits['hba1c'].mean()
# Out:
# 9.523257301215091

# %%
df_visits['systolic_pressure'].mean()
# Out:
# 124.79585020962126

# %%
df_visits['diastolic_pressure'].mean()
# Out:
# 89.99978682583671

# %%
df_visits.dtypes
# Out:
# patient_id              Int64
# visited_date           dbdate
# sugar                   Int64
# hba1c                 float64
# systolic_pressure       Int64
# diastolic_pressure      Int64
# dtype: object

# %% [markdown]
# ## Converting visited_date which is stored as a object to date using to_datetime

# %%
df_visits['visited_date'] = pd.to_datetime(df_visits['visited_date'])

# %%
df_visits.dtypes
# Out:
# patient_id                     Int64
# visited_date          datetime64[ns]
# sugar                          Int64
# hba1c                        float64
# systolic_pressure              Int64
# diastolic_pressure             Int64
# dtype: object

# %%
## Pandas to_datetime Documentation
## https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html

# %%
df_patients.dtypes
# Out:
# patient_id         Int64
# date_of_birth     dbdate
# aadhar_number      Int64
# mobile_number      Int64
# email             object
# first_name        object
# last_name         object
# full_name         object
# gender            object
# height             Int64
# weight             Int64
# bmi              float64
# area              object
# latitude         float64
# longitude        float64
# dtype: object

# %% [markdown]
# ## Converting date_of_birth of object type to date type

# %%
df_patients['date_of_birth'] = pd.to_datetime(df_patients['date_of_birth'])

# %%
df_patients.dtypes
# Out:
# patient_id                Int64
# date_of_birth    datetime64[ns]
# aadhar_number             Int64
# mobile_number             Int64
# email                    object
# first_name               object
# last_name                object
# full_name                object
# gender                   object
# height                    Int64
# weight                    Int64
# bmi                     float64
# area                     object
# latitude                float64
# longitude               float64
# dtype: object

# %% [markdown]
# ## Group By and finding mean Sugar, HBA1C, blood pressure

# %%
df_visits_groupbyid = df_visits.groupby('patient_id')

# %%
df_visits_groupbyid.mean()
# Out:
#                   visited_date       sugar      hba1c  systolic_pressure  \
# patient_id
# 1000       2023-06-16 12:00:00       281.5  12.650000              125.0
# 1001       2023-04-13 00:00:00       157.0   6.800000              102.0
# 1002       2023-09-09 06:00:00      515.25  12.175000              114.5
# 1003       2023-04-02 00:00:00       378.0  10.600000              107.0
# 1004       2023-07-28 16:00:00  398.666667  11.700000         121.666667
# ...                        ...         ...        ...                ...
# 5995       2023-07-26 16:00:00  592.666667  11.566667         123.666667
# 5996       2023-04-15 00:00:00       347.0  10.100000              121.0
# 5997       2023-04-18 00:00:00       474.0  11.100000              152.0
# 5998       2023-04-10 00:00:00        82.0   5.800000              146.0
# 5999       2023-07-12 00:00:00  356.333333  10.766667              115.0
#
#             diastolic_pressure
# patient_id
# 1000                      89.5
# 1001                      99.0
# 1002                     90.75
# 1003                      98.0
# 1004                 91.666667
# ...                        ...
# 5995                 90.666667
# 5996                      81.0
# 5997                      84.0
# 5998                      81.0
# 5999                 89.333333
#
# [5000 rows x 5 columns]

# %% [markdown]
# ## Finding Top 5 patients with maximum Sugar, HBA1C, Blood Pressure

# %%
df_visits.nlargest(5, 'sugar')
# Out:
#     patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 44        3979   2023-04-09    600    8.5                106
# 46        4795   2024-03-25    600    8.5                131
# 52        4084   2023-04-07    600    9.0                127
# 53        4707   2024-03-26    600    9.0                156
# 61        4104   2023-11-24    600    9.5                 97
#
#     diastolic_pressure
# 44                  80
# 46                  80
# 52                  80
# 53                  80
# 61                  80

# %%
df_visits.nlargest(5, 'hba1c')
# Out:
#       patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 118         1017   2023-08-08    217   14.0                150
# 119         3363   2023-11-06    245   14.0                154
# 781         2308   2023-08-03    541   14.0                158
# 782         3811   2023-04-07    455   14.0                 90
# 1437        2442   2023-07-30    377   14.0                125
#
#       diastolic_pressure
# 118                   80
# 119                   80
# 781                   81
# 782                   81
# 1437                  82

# %%
df_visits.nlargest(5, 'systolic_pressure')
# Out:
#      patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 128        3910   2023-07-31    112    5.3                160
# 208        5016   2023-04-07    414   10.1                160
# 246        1822   2023-11-08    527   12.6                160
# 264        2423   2023-04-26    100    5.1                160
# 349        4870   2023-08-03    566   10.2                160
#
#      diastolic_pressure
# 128                  80
# 208                  80
# 246                  80
# 264                  80
# 349                  80

# %%
df_visits.nlargest(5, 'diastolic_pressure')
# Out:
#        patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 13413        2120   2024-02-09    103    5.0                106
# 13414        2553   2023-11-22     89    5.0                101
# 13415        3108   2023-04-30    100    5.0                140
# 13416        3853   2023-04-05     66    5.0                102
# 13417        4880   2024-02-24     76    5.0                113
#
#        diastolic_pressure
# 13413                 100
# 13414                 100
# 13415                 100
# 13416                 100
# 13417                 100

# %% [markdown]
# ## Grouping, cutting, binning Sugar, HBA1C, Pressure
#
#    - For sugar the low range is between 50 to 80, normal is from 80 to 120, 120 to 160 is moderate, 160 - 200 is high, anything      above 200 is very high
#    - For HBA1C 5 - 6 is normal, 6 - 8 is controlled diabetes, 8 - 10 is high, beyond 80 is very high
#    - For BP systolic pressure till 110 is normal, 110 - 130 is high, beyond 130 is very high

# %%
sugar_bins = [50, 80, 120, 160, 200, 600]
sugar_labels = ['Low', 'Normal', 'Moderate', 'High', 'Very High']

hba1c_bins = [5, 6, 8, 10, 16]
hba1c_labels = ['Normal', 'Controlled Diabetes', 'High', 'Very High']

bp_bins = [80, 110, 130, 200]
bp_labels = ['Normal', 'High', 'Very High']

df_visits['sugar_cut'] = pd.cut(df_visits['sugar'], bins=sugar_bins, labels=sugar_labels)
df_visits['hba1c_cut'] = pd.cut(df_visits['hba1c'], bins=hba1c_bins, labels=hba1c_labels)
df_visits['bp_cut'] = pd.cut(df_visits['systolic_pressure'], bins=bp_bins, labels=bp_labels)

# %%
df_visits
# Out:
#        patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 0            1967   2024-03-13     85    5.0                 96
# 1            2172   2023-11-16    114    5.0                108
# 2            2239   2023-11-12     61    5.0                134
# 3            2749   2023-04-29     94    5.0                102
# 4            3635   2023-08-07     83    5.0                 90
# ...           ...          ...    ...    ...                ...
# 14068        3886   2024-02-17    295   13.9                135
# 14069        4996   2023-11-17    209   13.9                107
# 14070        5123   2023-04-30    449   13.9                129
# 14071        5655   2023-11-19    348   13.9                120
# 14072        5823   2023-10-21    238   13.9                130
#
#        diastolic_pressure  sugar_cut  hba1c_cut     bp_cut
# 0                      80     Normal        NaN     Normal
# 1                      80     Normal        NaN     Normal
# 2                      80        Low        NaN  Very High
# 3                      80     Normal        NaN     Normal
# 4                      80     Normal        NaN     Normal
# ...                   ...        ...        ...        ...
# 14068                 100  Very High  Very High  Very High
# 14069                 100  Very High  Very High     Normal
# 14070                 100  Very High  Very High       High
# 14071                 100  Very High  Very High       High
# 14072                 100  Very High  Very High       High
#
# [14073 rows x 9 columns]

# %%
df_visits['sugar_cut'].value_counts()
# Out:
# sugar_cut
# Very High    9696
# Moderate     1146
# High         1132
# Normal       1102
# Low           804
# Name: count, dtype: int64

# %%
df_visits['hba1c_cut'].value_counts()
# Out:
# hba1c_cut
# Very High              6399
# High                   3200
# Controlled Diabetes    2334
# Normal                 1996
# Name: count, dtype: int64

# %%
df_visits['bp_cut'].value_counts()
# Out:
# bp_cut
# Very High    5898
# Normal       4213
# High         3962
# Name: count, dtype: int64

# %%
## Reference article cut and qcut
## https://pbpython.com/pandas-qcut-cut.html

# %% [markdown]
# ## Extracting month and year

# %%
df_visits['year'] = df_visits['visited_date'].dt.year

# %%
df_visits.head()
# Out:
#    patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 0        1967   2024-03-13     85    5.0                 96
# 1        2172   2023-11-16    114    5.0                108
# 2        2239   2023-11-12     61    5.0                134
# 3        2749   2023-04-29     94    5.0                102
# 4        3635   2023-08-07     83    5.0                 90
#
#    diastolic_pressure sugar_cut hba1c_cut     bp_cut  year
# 0                  80    Normal       NaN     Normal  2024
# 1                  80    Normal       NaN     Normal  2023
# 2                  80       Low       NaN  Very High  2023
# 3                  80    Normal       NaN     Normal  2023
# 4                  80    Normal       NaN     Normal  2023

# %%
df_visits['month'] = df_visits['visited_date'].dt.month

# %%
df_visits.head()
# Out:
#    patient_id visited_date  sugar  hba1c  systolic_pressure  \
# 0        1967   2024-03-13     85    5.0                 96
# 1        2172   2023-11-16    114    5.0                108
# 2        2239   2023-11-12     61    5.0                134
# 3        2749   2023-04-29     94    5.0                102
# 4        3635   2023-08-07     83    5.0                 90
#
#    diastolic_pressure sugar_cut hba1c_cut     bp_cut  year  month
# 0                  80    Normal       NaN     Normal  2024      3
# 1                  80    Normal       NaN     Normal  2023     11
# 2                  80       Low       NaN  Very High  2023     11
# 3                  80    Normal       NaN     Normal  2023      4
# 4                  80    Normal       NaN     Normal  2023      8

# %%
## Ref article extracting month and year
## https://sparkbyexamples.com/pandas/pandas-extract-month-and-year-separately-from-datetime-column/#:~:text=Use%20pandas%20DatetimeIndex(),the%20corresponding%20month%20or%20year.

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## Line Chart Month, Year, Sugar

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(data=df_visits, x='month', y='sugar', hue='year', marker='o')

plt.xlabel('Month')
plt.ylabel('Sugar')
plt.title('Monthly Sugar Values for 2023 and 2024')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.savefig('monthly_sugar_values.png')
plt.show()

# %% [markdown]
# ## Line Chart Month, Year, HBA1C

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(data=df_visits, x='month', y='hba1c', hue='year', marker='o')

plt.xlabel('Month')
plt.ylabel('Sugar')
plt.title('HBA1C Values for 2023 and 2024')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.savefig('hba1c_values.png')
plt.show()

# %% [markdown]
# ## Line Chart Month, Year, BP

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(data=df_visits, x='month', y='systolic_pressure', hue='year', marker='o')

plt.xlabel('Month')
plt.ylabel('Pressure')
plt.title('Systolic Pressure Values for 2023 and 2024')
plt.xticks(ticks=range(1, 13), labels=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.grid(True)
plt.savefig('bp_values.png')
plt.show()

# %% [markdown]
# ## Histogram of Sugar

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df_visits['sugar'])

plt.xlabel('Total Sugar')
plt.ylabel('Frequency')
plt.title('Total Sugar Histogram')
plt.savefig('sugar_histogram.png')
plt.show()

# %% [markdown]
# ## Histogram of HBA1C

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df_visits['hba1c'])

plt.xlabel('Total HBA1C')
plt.ylabel('Frequency')
plt.title('Total HBA1C Histogram')
plt.savefig('hba1c_histogram.png')
plt.show()

# %% [markdown]
# ## Histogram of BP

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df_visits['systolic_pressure'])

plt.xlabel('Total Systolic Pressure')
plt.ylabel('Frequency')
plt.title('Total Systolic Pressure Histogram')
plt.savefig('systolic_pressure_histogram.png')
plt.show()

# %% [markdown]
# ## Bar Plot of Sugar Categories

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x = df_visits['sugar_cut'], data = df_visits)

plt.xlabel('Sugar Categories')
plt.ylabel('Frequency')
plt.title('Count of Sugar Categories')
plt.savefig('sugar_categories_bar.png')
plt.show()

# %% [markdown]
# ## Bar Plot of HBA1C Categories

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x = df_visits['hba1c_cut'], data = df_visits)

plt.xlabel('HBA1C Categories')
plt.ylabel('Frequency')
plt.title('Count of HBA1C Categories')
plt.savefig('hba1c_categories_bar.png')
plt.show()

# %% [markdown]
# ## Bar Plot of BP Categories

# %%
plt.figure(figsize=(10, 6))

sns.countplot(x = df_visits['bp_cut'], data = df_visits)

plt.xlabel('BP Categories')
plt.ylabel('Frequency')
plt.title('Count of Blood Pressure Categories')
plt.savefig('bp_categories_bar.png')
plt.show()

# %% [markdown]
# ## Relationship Between Sugar And HBA1C (Scatterplot)

# %%
plt.figure(figsize=(10, 6))

sns.regplot(x = df_visits['sugar'], y = df_visits['hba1c'], data = df_visits)

plt.xlabel('Sugar')
plt.ylabel('HBA1C')
plt.title('Scatterplot of Sugar and HBA1C')
plt.savefig('sugar_hba1c_scatter.png')
plt.show()

# %% [markdown]
# ## Box Plot of Total Sugar

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = df_visits['sugar'], data = df_visits)

plt.xlabel('Sugar')
plt.title('Box Plot of Sugar')
plt.savefig('sugar_box.png')
plt.show()

# %% [markdown]
# ## Box Plot of HBA1C

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = df_visits['hba1c'], data = df_visits)

plt.xlabel('Sugar')
plt.title('Box Plot of HBA1C')
plt.savefig('hba1c_box.png')
plt.show()

# %% [markdown]
# ## Box Plot of BP

# %%
plt.figure(figsize=(10, 6))

sns.boxplot(x = df_visits['systolic_pressure'], data = df_visits)

plt.xlabel('Blood Pressure')
plt.title('Box Plot of Blood Pressure')
plt.savefig('bp_box.png')
plt.show()

# %% [markdown]
# ## Finding the Correlation Between Sugar and HBA1C

# %%
correlation = df_visits[['sugar', 'hba1c']].corr()

# %%
correlation
# Out:
#           sugar     hba1c
# sugar  1.000000  0.645261
# hba1c  0.645261  1.000000

# %% [markdown]
# ## Heatmap of Correlation Between Sugar and HBA1C

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm', linewidths=.5, vmin=-1, vmax=1)

plt.title('Correlation Between Sugar and HbA1c')
plt.savefig('correlation_heatmap.png')
plt.show()

# %% [markdown]
# ## Finding whether there is any relationship between Age and HBA1C

# %%
df_patients.dtypes
# Out:
# patient_id                Int64
# date_of_birth    datetime64[ns]
# aadhar_number             Int64
# mobile_number             Int64
# email                    object
# first_name               object
# last_name                object
# full_name                object
# gender                   object
# height                    Int64
# weight                    Int64
# bmi                     float64
# area                     object
# latitude                float64
# longitude               float64
# dtype: object

# %%
reference_date = pd.Timestamp('2024-01-01')
df_patients['age'] = df_patients['date_of_birth'].apply(lambda dob: reference_date.year - dob.year - ((reference_date.month, reference_date.day) < (dob.month, dob.day)))

# %%
df_patients
# Out:
#       patient_id date_of_birth  aadhar_number  mobile_number  \
# 0           1053    1973-04-24   317320301691   917108801293
# 1           1111    1990-06-25   228343284543   914826294247
# 2           1128    1949-01-06   819907684377   915974958012
# 3           1132    1960-01-13   612453976088   918818220132
# 4           1212    1967-04-17   384827959428   915647948599
# ...          ...           ...            ...            ...
# 4995        5778    1952-07-06   759745250273   913136394236
# 4996        5782    1950-07-22   892457571342   913355283689
# 4997        5798    1991-05-17   210853042414   915457454819
# 4998        5891    1976-05-04    41932755662   919094900415
# 4999        5894    1984-11-15   714359032616   911677836843
#
#                              email    first_name        last_name  \
# 0                frose@example.net       Pandian         Govindan
# 1     danielleanderson@example.com  Chandrasekar       Bhagavathi
# 2           jerryfrank@example.net        Naveen         Rathinam
# 3            moodyryan@example.com        Harish          Senthil
# 4           scottjones@example.com  Chandrasekar       Palanisamy
# ...                            ...           ...              ...
# 4995       mwashington@example.com    Ezhilarasi  Balasubramanian
# 4996         michael29@example.net           Uma  Balasubramanian
# 4997         lorilopez@example.net     Kalaivani    Parthasarathy
# 4998       martindiana@example.net        Tanuja     Thirumurugan
# 4999           qmurray@example.org         Jothi       Kasinathan
#
#                            full_name  gender  height  weight   bmi  \
# 0               Mr. Pandian Govindan    Male     169      57  20.0
# 1        Mr. Chandrasekar Bhagavathi    Male     157      65  26.4
# 2                Mr. Naveen Rathinam    Male     151      57  25.0
# 3                 Mr. Harish Senthil    Male     169      96  33.6
# 4        Mr. Chandrasekar Palanisamy    Male     155      75  31.2
# ...                              ...     ...     ...     ...   ...
# 4995  Ms. Ezhilarasi Balasubramanian  Female     174      71  23.5
# 4996         Ms. Uma Balasubramanian  Female     172      94  31.8
# 4997     Ms. Kalaivani Parthasarathy  Female     162      55  21.0
# 4998         Ms. Tanuja Thirumurugan  Female     148      97  44.3
# 4999            Ms. Jothi Kasinathan  Female     146      68  31.9
#
#             area  latitude  longitude  age
# 0      Mandaveli    13.029     80.259   50
# 1      Mandaveli    13.029     80.259   33
# 2      Mandaveli    13.029     80.259   74
# 3      Mandaveli    13.029     80.259   63
# 4      Mandaveli    13.029     80.259   56
# ...          ...       ...        ...  ...
# 4995  Pallavaram    12.967     80.145   71
# 4996  Pallavaram    12.967     80.145   73
# 4997  Pallavaram    12.967     80.145   32
# 4998  Pallavaram    12.967     80.145   47
# 4999  Pallavaram    12.967     80.145   39
#
# [5000 rows x 16 columns]

# %%
df_visits.dtypes
# Out:
# patient_id                     Int64
# visited_date          datetime64[ns]
# sugar                          Int64
# hba1c                        float64
# systolic_pressure              Int64
# diastolic_pressure             Int64
# sugar_cut                   category
# hba1c_cut                   category
# bp_cut                      category
# year                           int32
# month                          int32
# dtype: object

# %%
# Calculate the average HbA1c for each patient
avg_hba1c = df_visits.groupby('patient_id')['hba1c'].mean().reset_index()

# %%
avg_hba1c
# Out:
#       patient_id      hba1c
# 0           1000  12.650000
# 1           1001   6.800000
# 2           1002  12.175000
# 3           1003  10.600000
# 4           1004  11.700000
# ...          ...        ...
# 4995        5995  11.566667
# 4996        5996  10.100000
# 4997        5997  11.100000
# 4998        5998   5.800000
# 4999        5999  10.766667
#
# [5000 rows x 2 columns]

# %%
avg_hba1c.rename(columns={'hba1c': 'avg_hba1c'}, inplace=True)

# %%
avg_hba1c
# Out:
#       patient_id  avg_hba1c
# 0           1000  12.650000
# 1           1001   6.800000
# 2           1002  12.175000
# 3           1003  10.600000
# 4           1004  11.700000
# ...          ...        ...
# 4995        5995  11.566667
# 4996        5996  10.100000
# 4997        5997  11.100000
# 4998        5998   5.800000
# 4999        5999  10.766667
#
# [5000 rows x 2 columns]

# %%
# Merge the average HbA1c data with df_patients
df_patients = pd.merge(df_patients, avg_hba1c, on='patient_id')

# %%
df_patients
# Out:
#       patient_id date_of_birth  aadhar_number  mobile_number  \
# 0           1053    1973-04-24   317320301691   917108801293
# 1           1111    1990-06-25   228343284543   914826294247
# 2           1128    1949-01-06   819907684377   915974958012
# 3           1132    1960-01-13   612453976088   918818220132
# 4           1212    1967-04-17   384827959428   915647948599
# ...          ...           ...            ...            ...
# 4995        5778    1952-07-06   759745250273   913136394236
# 4996        5782    1950-07-22   892457571342   913355283689
# 4997        5798    1991-05-17   210853042414   915457454819
# 4998        5891    1976-05-04    41932755662   919094900415
# 4999        5894    1984-11-15   714359032616   911677836843
#
#                              email    first_name        last_name  \
# 0                frose@example.net       Pandian         Govindan
# 1     danielleanderson@example.com  Chandrasekar       Bhagavathi
# 2           jerryfrank@example.net        Naveen         Rathinam
# 3            moodyryan@example.com        Harish          Senthil
# 4           scottjones@example.com  Chandrasekar       Palanisamy
# ...                            ...           ...              ...
# 4995       mwashington@example.com    Ezhilarasi  Balasubramanian
# 4996         michael29@example.net           Uma  Balasubramanian
# 4997         lorilopez@example.net     Kalaivani    Parthasarathy
# 4998       martindiana@example.net        Tanuja     Thirumurugan
# 4999           qmurray@example.org         Jothi       Kasinathan
#
#                            full_name  gender  height  weight   bmi  \
# 0               Mr. Pandian Govindan    Male     169      57  20.0
# 1        Mr. Chandrasekar Bhagavathi    Male     157      65  26.4
# 2                Mr. Naveen Rathinam    Male     151      57  25.0
# 3                 Mr. Harish Senthil    Male     169      96  33.6
# 4        Mr. Chandrasekar Palanisamy    Male     155      75  31.2
# ...                              ...     ...     ...     ...   ...
# 4995  Ms. Ezhilarasi Balasubramanian  Female     174      71  23.5
# 4996         Ms. Uma Balasubramanian  Female     172      94  31.8
# 4997     Ms. Kalaivani Parthasarathy  Female     162      55  21.0
# 4998         Ms. Tanuja Thirumurugan  Female     148      97  44.3
# 4999            Ms. Jothi Kasinathan  Female     146      68  31.9
#
#             area  latitude  longitude  age  avg_hba1c
# 0      Mandaveli    13.029     80.259   50     11.600
# 1      Mandaveli    13.029     80.259   33      9.750
# 2      Mandaveli    13.029     80.259   74     11.925
# 3      Mandaveli    13.029     80.259   63     11.400
# 4      Mandaveli    13.029     80.259   56      5.475
# ...          ...       ...        ...  ...        ...
# 4995  Pallavaram    12.967     80.145   71      5.550
# 4996  Pallavaram    12.967     80.145   73      5.300
# 4997  Pallavaram    12.967     80.145   32      8.625
# 4998  Pallavaram    12.967     80.145   47      6.300
# 4999  Pallavaram    12.967     80.145   39     11.450
#
# [5000 rows x 17 columns]

# %%
# The relationship between age and average HbA1c
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='avg_hba1c', data=df_patients)
sns.regplot(x='age', y='avg_hba1c', data=df_patients, scatter=False, color='r')
plt.xlabel('Age')
plt.ylabel('Average HbA1c')
plt.title('Relationship between Age and Average HbA1c')
plt.show()

# %%
df_visits.columns
# Out:
# Index(['patient_id', 'visited_date', 'sugar', 'hba1c', 'systolic_pressure',
#        'diastolic_pressure', 'sugar_cut', 'hba1c_cut', 'bp_cut', 'year',
#        'month'],
#       dtype='object')

# %% [markdown]
# ## Statistical Analysis - Chi Squared Test
#
# - The chi-squared tests are used to test the independence between categorical variables
# - It is used to measure the departure from the mean with respect to category counts.
# - The statistic that measure the extent to which results depart from the null expectation of independence is the chi-squared statistic
# - chi-squared statistic = [observed - expected value] / [sqrt of expected value]

# %%
# Create a contingency table
contingency_table = pd.crosstab(df_visits['sugar_cut'], df_visits['hba1c_cut'])

print("Contingency Table:")
print(contingency_table)

# Perform chi-squared test
chi2, p, dof, expected = chi2_contingency(contingency_table)

print("\nResults of Chi-squared Test:")
print(f"Chi-squared statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
alpha = 0.05
if p < alpha:
    print("\nThere is a significant association between sugar_cut and hba1c_cut.")
else:
    print("\nThe association between sugar_cut and hba1c_cut is not significant.")
# Out:
# Contingency Table:
# hba1c_cut  Normal  Controlled Diabetes  High  Very High
# sugar_cut
# Low           758                    0     0          0
# Normal       1022                    0     0          0
# Moderate       22                 1124     0          0
# High           19                 1113     0          0
# Very High       0                   97  3200       6399
#
# Results of Chi-squared Test:
# Chi-squared statistic: 26263.197169081344
# P-value: 0.0
# Degrees of freedom: 12
# Expected frequencies:
# [[ 100.35756871  128.62963502  176.35596917  352.6568271 ]
#  [ 135.31060055  173.42940236  237.77810092  475.48189618]
#  [ 151.72793369  194.47171732  266.62789007  533.17245892]
#  [ 149.87436382  192.09597208  263.37065581  526.65900829]
#  [1283.72953323 1645.37327323 2255.86738403 4511.02980951]]
#
# There is a significant association between sugar_cut and hba1c_cut.

# %% [markdown]
# ## Interpretation of Analytical Results
#
# * There is strong correlaton between sugar and HBA1C
# * The correlation between high and low BP are not checked since they keep changing
# * The sugar values are skewed towards high sugar levels
# * The HBA1C levels are skewed towards high HBA1C levels
# * The HBA1C is equally distributed among people of all ages
# * The BP values are almost normally distributed
# * The visualizations indicate that there are more patients with higher HBA1C and Sugar
# * The chi-square contingency report indicates that there is significant association between sugar and hba1c
